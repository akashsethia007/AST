# %%
##Find 52 Week hogh stocks



# Directly get a list of all stocks at 52-week high
top_highs = nse.get_52_week_high()

for stock in top_highs:
    print(f"Symbol: {stock['symbol']}, LTP: {stock['ltp']}, New High: {stock['new52WHL']}")

# %%
from nsetools import Nse

# %%
nse=Nse()

# %%
top_highs = nse.get_52_week_high()

# %%
print(type(top_highs))
# Out:
# <class 'list'>

# %%
stk = ['AMCL', 'HDFCQUAL']
for stocks in top_highs:
    if stocks['symbol'] in stk:
        print("HERE IT IS")
        print(stocks['new52WHL'])
        print(stocks)
# Out:
# HERE IT IS
# 371
# {'symbol': 'AMCL', 'series': 'ST', 'comapnyName': 'ANB Metal Cast Limited', 'new52WHL': 371, 'prev52WHL': 370.7, 'prevHLDate': '22-Dec-2025', 'ltp': 370, 'prevClose': 367, 'change': 3, 'pChange': 0.82}
# HERE IT IS
# 60.98
# {'symbol': 'HDFCQUAL', 'series': 'EQ', 'comapnyName': 'HDFC Mutual Fund - HDFC NIFTY100 Quality 30 ETF', 'new52WHL': 60.98, 'prev52WHL': 60.98, 'prevHLDate': '24-Dec-2025', 'ltp': 60.33, 'prevClose': 60.68, 'change': -0.35, 'pChange': -0.58}

# %%
for stock in top_highs:
    print(f"Symbol: {stock['symbol']}, LTP: {stock['ltp']}, New High: {stock['new52WHL']}")
# Out:
# Symbol: AIAENG, LTP: 3911, New High: 3999
# Symbol: AMCL, LTP: 370, New High: 371
# Symbol: ANONDITA, LTP: 867, New High: 867
# Symbol: ANONDITA, LTP: 867, New High: 867
# Symbol: ARFIN, LTP: 68.71, New High: 70.93
# Symbol: ASHAPURMIN, LTP: 877.8, New High: 901.5
# Symbol: ASHOKLEY, LTP: 175.19, New High: 178.3
# Symbol: ASIANTILES, LTP: 77.28, New High: 78.8
# Symbol: ASLIND, LTP: 118.6, New High: 118.6
# Symbol: ASLIND, LTP: 118.6, New High: 118.6
# Symbol: AXISGOLD, LTP: 114.3, New High: 117.5
# Symbol: AXISILVER, LTP: 217.8, New High: 217.99
# Symbol: AXITA, LTP: 13.07, New High: 13.1
# Symbol: BBNPPGOLD, LTP: 132.65, New High: 135.15
# Symbol: BHARATFORG, LTP: 1451, New High: 1470.6
# Symbol: BSLNIFTY, LTP: 30.39, New High: 31.18
# Symbol: CANFINHOME, LTP: 948.45, New High: 948.5
# Symbol: CANFINHOME, LTP: 946.2, New High: 948.5
# Symbol: CHOICEGOLD, LTP: 135.81, New High: 137
# Symbol: CONNPLEX, LTP: 261.5, New High: 272.5
# Symbol: CONNPLEX, LTP: 261.5, New High: 272.5
# ...

# %% [markdown]
# from nsetools import Nse
#
# nse = Nse()
# # Directly get a list of all stocks at 52-week high
# top_highs = nse.get_52_week_high()
#
# for stock in top_highs:
#     print(f"Symbol: {stock['symbol']}, LTP: {stock['ltp']}, New High: {stock['new52WHL']}")
